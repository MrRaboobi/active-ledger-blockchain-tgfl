# %% [markdown]
# # Phase 3.2: Session 2 (Part A) — Multi-Krum + Blind Diffusion
#
# This notebook tests the strongest statistical baseline (Multi-Krum) augmented with Latent Diffusion. It runs completely sequentially and isolated to ensure absolutely zero data leakage across methods.

# %%
# 1. Environment Setup
# !pip install -q diffusers accelerate web3 py-evm

# %%
# 2. Unzip Repository and Dataset
import os
import zipfile

# Assuming you upload 'FYP-Blockchain-FL.zip' to the Kaggle input directory
zip_path = "/kaggle/input/fyp-code/FYP-Blockchain-FL.zip" # UPDATE IF NEEDED
extract_path = "/kaggle/working/FYP-Blockchain-FL"

if os.path.exists(zip_path) and not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

os.chdir(extract_path)
print("Working directory set to:", os.getcwd())

# %%
# 3. Run Session 2 Part A (Multi-Krum + Blind Diffusion)
# Note: This does not need Ganache, so we skip blockchain initialization.
# !python benchmarks/run_session2_multikrum.py
