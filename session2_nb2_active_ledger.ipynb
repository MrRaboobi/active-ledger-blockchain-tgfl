# %% [markdown]
# # Phase 3.2: Session 2 (Part B) — Active-Ledger Full System
#
# This notebook tests your proposed system: PoC-Gated Blockchain + Latent Diffusion. It runs completely isolated from Session 1 and from Part A to guarantee zero memory leakage.

# %%
# 1. Environment Setup
# !pip install -q diffusers accelerate web3 py-evm

# %%
# 2. Ganache Installation (Required for Trust Gate)
# !npm install -g ganache-cli

# %%
# 3. Start Ganache Background Server
import subprocess
import time

print("Starting Ganache CLI on port 8545...")
ganache_process = subprocess.Popen(
    ["ganache-cli", "-p", "8545", "-a", "15"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)
time.sleep(5)  # Wait for server to boot
print("Ganache Server Running.")

# %%
# 4. Unzip Repository and Dataset
import os
import zipfile

# Assuming you upload 'FYP-Blockchain-FL.zip' to the Kaggle input directory
zip_path = "/kaggle/input/fyp-code/FYP-Blockchain-FL.zip" # UPDATE IF NEEDED
extract_path = "/kaggle/working/FYP-Blockchain-FL"

if os.path.exists(zip_path) and not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

os.chdir(extract_path)
print("Working directory set to:", os.getcwd())

# %%
# 5. Run Session 2 Part B (Active-Ledger PoC + Diffusion)
# !python benchmarks/run_session2_active_ledger.py
